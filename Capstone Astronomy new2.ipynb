# %% [markdown]
# First, we need to import the two CSV files

# %%
import pandas as pd
import sqlite3 as sql

dfComposite = pd.read_csv('data/NASA_Exoplanet_Composite.csv')

dfPlanetary = pd.read_csv('data/NASA_Exoplanet_Planetary.csv', low_memory=False)

# %% [markdown]
# To protect the data I will be working with copies of each csv.

# %%
Composite = dfComposite.copy()
Planetary = dfPlanetary.copy()

# %% [raw]
# Lets take a look at the data that is available to be used on this project.  Exoplanets have a variety of characterists which NASA has breifly summarized in an animated video. I have a link to this in my readme.  You can also use the code block below.  After, the video is a code block that displays each of the csv files.

# %%
# %%HTML
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/4IXYp9Fse44"
# </iframe>
# Out:
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/4IXYp9Fse44"
# </iframe>

# %%
display(Composite)
display(Planetary)
# Out:
#       rowid     pl_name  hostname pl_letter    hd_name    hip_name  \
# 0         1    11 Com b    11 Com         b  HD 107383   HIP 60202
# 1         2    11 UMi b    11 UMi         b  HD 136726   HIP 74793
# 2         3    14 And b    14 And         b  HD 221345  HIP 116076
# 3         4    14 Her b    14 Her         b  HD 145675   HIP 79248
# 4         5  16 Cyg B b  16 Cyg B         b  HD 186427   HIP 96901
# ...     ...         ...       ...       ...        ...         ...
# 5478   5479   ups And b   ups And         b    HD 9826    HIP 7513
# 5479   5480   ups And c   ups And         c    HD 9826    HIP 7513
# 5480   5481   ups And d   ups And         d    HD 9826    HIP 7513
# 5481   5482   ups Leo b   ups Leo         b        NaN         NaN
# 5482   5483    xi Aql b    xi Aql         b  HD 188310   HIP 97938
#
#              tic_id                       gaia_id  sy_snum  sy_pnum  ...  \
# 0      TIC 72437047  Gaia DR2 3946945413106333696        2        1  ...
# ...

# %% [markdown]
# As you can see there is quite a bit of information in each of these CSV files.  More so in the Planetary csv. So, lets clean it up by keeping the first instance of each planet name.

# %%
Planetary = Planetary.drop_duplicates(subset=['pl_name'], keep='first')

##  fix index numbering and row ids

display(Planetary)
# Out:
#        rowid     pl_name  hostname pl_letter    hd_name    hip_name  \
# 0          1    11 Com b    11 Com         b  HD 107383   HIP 60202
# 2          3    11 UMi b    11 UMi         b  HD 136726   HIP 74793
# 5          6    14 And b    14 And         b  HD 221345  HIP 116076
# 7          8    14 Her b    14 Her         b  HD 145675   HIP 79248
# 15        16  16 Cyg B b  16 Cyg B         b  HD 186427   HIP 96901
# ...      ...         ...       ...       ...        ...         ...
# 34929  34930   ups And b   ups And         b    HD 9826    HIP 7513
# 34936  34937   ups And c   ups And         c    HD 9826    HIP 7513
# 34942  34943   ups And d   ups And         d    HD 9826    HIP 7513
# 34948  34949   ups Leo b   ups Leo         b        NaN         NaN
# 34949  34950    xi Aql b    xi Aql         b  HD 188310   HIP 97938
#
#               tic_id                       gaia_id  default_flag  sy_snum  \
# 0       TIC 72437047  Gaia DR2 3946945413106333696             0        2
# ...

# %% [markdown]
# To clean the data further, lets delete any columns that won't be needed for this project.

# %%
#Comp = Composite.drop(Composite.columns[[14-15, 20-161, 165-182, 186-213, 216-226, 230-282, 287-298, 302-306, 308-324 ]], axis=1, inplace=True)
#Planet = Planetary.drop(Planetary.columns[[14-15, 20-161, 165-182, 186-213, 216-226, 230-282, 287-298, 302-306, 308-324 ]], axis=1, inplace=True)
#display(Composite)
#display(Planetary)

##OR
# Drop columns by index range
##df = df.drop(df.columns[0:2], axis=1)  # This removes the first two columns

##2) keep the columns that I will need.'
##df = df.loc[:, ['pl_name','pl_location, ']]


columns = ['pl_name', 'pul_flag']
Planetary = Planetary[columns] 

columns = ['pl_name', 'pl_letter', 'hd_name', 'gaia_id', 'sy_snum', 'sy_pnum', 'sy_mnum', 'discoverymethod', 'disc_year', 'disc_locale', 'disc_facility', 'disc_telescope' ]
Composite = Composite[columns]

# %% [markdown]
# The next step is to merge the two files.  We are concatinating the data

# %%
merged_df = pd.concat([Composite, Planetary], ignore_index=True)
merged_df.to_csv('merged.csv', index=False)
merged_df.head()
# Out:
#       pl_name pl_letter    hd_name                       gaia_id  sy_snum  \
# 0    11 Com b         b  HD 107383  Gaia DR2 3946945413106333696      2.0
# 1    11 UMi b         b  HD 136726  Gaia DR2 1696798367260229376      1.0
# 2    14 And b         b  HD 221345  Gaia DR2 1920113512486282240      1.0
# 3    14 Her b         b  HD 145675  Gaia DR2 1385293808145621504      1.0
# 4  16 Cyg B b         b  HD 186427  Gaia DR2 2135550755683407232      3.0
#
#    sy_pnum  sy_mnum  discoverymethod  disc_year disc_locale  \
# 0      1.0      0.0  Radial Velocity     2007.0      Ground
# 1      1.0      0.0  Radial Velocity     2009.0      Ground
# 2      1.0      0.0  Radial Velocity     2008.0      Ground
# 3      2.0      0.0  Radial Velocity     2002.0      Ground
# 4      1.0      0.0  Radial Velocity     1996.0      Ground
#
#                             disc_facility                 disc_telescope  \
# 0                        Xinglong Station               2.16 m Telescope
# ...

# %% [markdown]
# I want to concentrate on planets with the classes C, D, and E. To acheive this I will make some more changes to the data.

# %%
## 1) select planet types C, D and E.
# %%sql

SELECT * FROM merged.csv
    WHERE column.pl_letter = 'c';

#add count for each
# Out:
#   Cell In[52], line 4
#     SELECT * FROM merged.csv
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# The csv files did not have the distance from the Earth, so that will be added now.

# %%
##  Add column with the light years from earth for each planet.

# %% [markdown]
# Now we need to visualize the data in three ways, Tableau will be used for these:
# 1) show how, where the planet was discovered
# 2) The facility and the type of telescope that was used
# 3) The name of the planet and how many light years from earth

# %%
## 1) show how, where the planet was discovered

# %%
## 2) The facility and the type of telescope that was used

# %%
## 3) The name of the planet and how many light years from earth
